# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns 

data=pd.read_csv("shopping_trends.csv")
data
# Out:
#       Customer ID  Age  Gender Item Purchased     Category  \
# 0               1   55    Male         Blouse     Clothing
# 1               2   19    Male        Sweater     Clothing
# 2               3   50    Male          Jeans     Clothing
# 3               4   21    Male        Sandals     Footwear
# 4               5   45    Male         Blouse     Clothing
# ...           ...  ...     ...            ...          ...
# 3895         3896   40  Female         Hoodie     Clothing
# 3896         3897   52  Female       Backpack  Accessories
# 3897         3898   46  Female           Belt  Accessories
# 3898         3899   44  Female          Shoes     Footwear
# 3899         3900   52  Female        Handbag  Accessories
#
#       Purchase Amount (USD)       Location Size      Color  Season  \
# 0                        53       Kentucky    L       Gray  Winter
# 1                        64          Maine    L     Maroon  Winter
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Age Distribution
plt.figure(figsize=(10, 6))
sns.histplot(data['Age'], bins=20, kde=True)
plt.title('Age Distribution of Customers')
plt.xlabel('Age')
plt.ylabel('Frequency')
plt.show()

# Gender Distribution
plt.figure(figsize=(10, 6))
sns.countplot(x='Gender', data=data)
plt.title('Gender Distribution of Customers')
plt.xlabel('Gender')
plt.ylabel('Count')
plt.show()


import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Plot the violin plot
plt.figure(figsize=(12, 8))
sns.violinplot(x='Gender', y='Age', data=data)
plt.title('Age and Gender Distribution of Customers')
plt.xlabel('Gender')
plt.ylabel('Age')
plt.show()

# %% [markdown]
# 1. **Age Distribution by Gender**: The plot shows the distribution of ages for each gender. We can see the range of ages for both males and females, as well as the concentration of ages within each gender. For example, if the plot shows a wider spread for females, it indicates a more diverse age range among female customers.
#
# 2. **Median Age**: The plot highlights the median age for each gender. If the median age for males is higher than for females, it suggests that male customers tend to be older on average.
#
# 3. **Age Variability**: The width of the violin plot indicates the variability in ages within each gender. A wider plot suggests greater variability, while a narrower plot indicates more consistency in ages.
#
# 4. **Outliers**: The plot can also reveal any outliers in the data. These are ages that are significantly higher or lower than the rest of the data. Outliers can provide insights into unique customer segments.
#
# 5. **Gender Comparison**: By comparing the distributions for males and females, we can identify any significant differences in age demographics between the two genders. This can help tailor marketing strategies to better target each gender.

# %%
import pandas as pd
import matplotlib.pyplot as plt

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Calculate the distribution of product categories
category_counts = data['Category'].value_counts()

# Plot the pie chart
plt.figure(figsize=(10, 8))
plt.pie(category_counts, labels=category_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Product Category Distribution')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show
# Out:
# <function matplotlib.pyplot.show(close=None, block=None)>

# %% [markdown]
# 1. **Popular Product Categories**: The chart highlights the most popular product categories based on the proportion of total purchases. For example, if "Clothing" occupies the largest segment, it indicates that clothing items are the most frequently purchased products.
#
# 2. **Least Popular Categories**: Similarly, the chart shows the least popular product categories. If "Accessories" has the smallest segment, it suggests that accessories are less frequently purchased compared to other categories.
#
# 3. **Market Demand**: The distribution of product categories provides insights into market demand. Categories with larger segments indicate higher demand, which can help businesses focus their inventory and marketing efforts on these products.
#
# 4. **Customer Preferences**: The chart can reveal customer preferences for different types of products. Understanding these preferences can help businesses tailor their product offerings to better meet customer needs.
#
# 5. **Sales Strategy**: The distribution can inform sales strategies. For example, if certain categories are underperforming, businesses might consider promotions or discounts to boost sales in those areas.
#
# 6. **Inventory Management**: Knowing which categories are most and least popular can help with inventory management. Businesses can ensure they have sufficient stock of high-demand items and avoid overstocking less popular products.

# %%
# Count the number of purchases by season
season_counts = data['Season'].value_counts()

# Plot the pie chart
plt.figure(figsize=(8, 8))
plt.pie(season_counts, labels=season_counts.index, autopct='%1.1f%%', startangle=140)
plt.title('Purchases by Season')
plt.axis('equal')  # Equal aspect ratio ensures that pie is drawn as a circle.
plt.show()

# %% [markdown]
# 1. **Seasonal Trends**: The graph highlights the seasonal trends in customer purchases. For example, if the graph shows a peak in purchases during the winter season, it indicates that customers tend to shop more during this time.
#
# 2. **High and Low Seasons**: The graph can help identify the high and low seasons for purchases. If summer has the lowest count, it suggests that summer is a slower season for sales.
#
# 3. **Marketing Opportunities**: Understanding the seasonal trends can help businesses plan their marketing campaigns more effectively. For instance, businesses can offer special promotions or discounts during low seasons to boost sales.
#
# 4. **Inventory Management**: Knowing which seasons have higher purchase counts can help with inventory management. Businesses can ensure they have sufficient stock during high seasons to meet customer demand.
#
# 5. **Customer Behavior**: The graph provides insights into customer behavior and preferences during different seasons. This can help businesses tailor their product offerings and marketing strategies to better meet customer needs.

# %%
# Shipping Types
plt.figure(figsize=(10, 6))
sns.countplot(x='Shipping Type', data=data, order=data['Shipping Type'].value_counts().index)
plt.title('Shipping Preferences')
plt.xlabel('Shipping Type')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 1. **Preferred Shipping Methods**: The graph highlights the most preferred shipping methods among customers. For example, if "Express" shipping has the highest count, it indicates that a significant number of customers prefer faster delivery options.
#
# 2. **Least Preferred Shipping Methods**: Similarly, the graph shows the least preferred shipping methods. If "Store Pickup" has the lowest count, it suggests that fewer customers opt for this method.
#
# 3. **Customer Expectations**: The distribution of shipping types can provide insights into customer expectations regarding delivery times. A higher preference for express or next-day shipping indicates that customers value quick delivery.
#
# 4. **Shipping Costs**: The graph can also reflect customer sensitivity to shipping costs. If free shipping options have a high count, it suggests that customers are more likely to choose cost-effective shipping methods.
#
# 5. **Logistics and Operations**: Understanding the preferred shipping methods can help businesses optimize their logistics and operations. They can allocate resources to ensure efficient handling of the most popular shipping types.
#
# 6. **Marketing Strategies**: The data can inform marketing strategies. For instance, businesses can offer promotions on less preferred shipping methods to encourage their use or highlight the benefits of faster shipping options.
# .

# %%
# Frequency of Purchases
plt.figure(figsize=(10, 6))
sns.countplot(x='Frequency of Purchases', data=data, order=data['Frequency of Purchases'].value_counts().index)
plt.title('Frequency of Purchases')
plt.xlabel('Frequency of Purchases')
plt.ylabel('Count')
plt.show()

# %% [markdown]
# 1. **Most Common Purchase Frequency**: The graph highlights the most common frequency of purchases among customers. For example, if "Weekly" purchases have the highest count, it indicates that a significant number of customers make purchases on a weekly basis.
#
# 2. **Least Common Purchase Frequency**: Similarly, the graph shows the least common purchase frequency. If "Annually" has the lowest count, it suggests that very few customers make purchases once a year.
#
# 3. **Customer Engagement**: The distribution of purchase frequencies can provide insights into customer engagement. Higher frequencies (e.g., daily or weekly) indicate more engaged customers who frequently interact with the business.
#
# 4. **Marketing Opportunities**: Understanding the distribution of purchase frequencies can help identify marketing opportunities. For instance, customers who purchase less frequently (e.g., monthly or quarterly) might be targeted with special promotions to encourage more frequent purchases.
#
# 5. **Customer Segmentation**: The graph can help in segmenting customers based on their purchase behavior. Different strategies can be developed for high-frequency purchasers versus low-frequency purchasers.
#
# 6. **Business Performance**: The overall distribution of purchase frequencies can provide insights into the business's performance and customer loyalty. A higher proportion of frequent purchasers indicates strong customer loyalty and satisfaction.

# %%
# Impact of Discounts
plt.figure(figsize=(10, 6))
sns.boxplot(x='Discount Applied', y='Purchase Amount (USD)', data=data)
plt.title('Impact of Discounts on Purchase Amount')
plt.xlabel('Discount Applied')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# Impact of Promo Codes
plt.figure(figsize=(10, 6))
sns.boxplot(x='Promo Code Used', y='Purchase Amount (USD)', data=data)
plt.title('Impact of Promo Codes on Purchase Amount')
plt.xlabel('Promo Code Used')
plt.ylabel('Purchase Amount (USD)')
plt.show()

# %% [markdown]
# ### Impact of Discounts
# - The box plot for discounts shows the distribution of purchase amounts for transactions where discounts were applied versus those where they were not.
# - If the median purchase amount is higher for transactions with discounts, it suggests that discounts encourage customers to spend more.
# - The spread of the data (interquartile range) can indicate the variability in purchase amounts. A wider spread for discounted purchases might suggest that discounts attract a broader range of spending behaviors.
#
# ### Impact of Promo Codes
# - The box plot for promo codes shows the distribution of purchase amounts for transactions where promo codes were used versus those where they were not.
# - Similar to discounts, if the median purchase amount is higher for transactions with promo codes, it suggests that promo codes incentivize higher spending.
# - The presence of outliers in the box plot can indicate exceptional cases where promo codes led to significantly higher or lower purchase amounts.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Calculate the max and min values
location_counts = data['Location'].value_counts()
max_location = location_counts.idxmax()
max_count = location_counts.max()
min_location = location_counts.idxmin()
min_count = location_counts.min()

# Plot the geographical analysis with larger labels
plt.figure(figsize=(20, 18))
sns.countplot(y='Location', data=data, order=location_counts.index)
plt.title('Sales by Location', fontsize=20)
plt.xlabel('Count', fontsize=15)
plt.ylabel('Location', fontsize=15)
plt.xticks(fontsize=12)
plt.yticks(fontsize=12)
plt.show()

# Print the max and min values
print(f"Location with the maximum sales: {max_location} ({max_count} sales)")
print(f"Location with the minimum sales: {min_location} ({min_count} sales)")
# Out:
# Location with the maximum sales: Montana (96 sales)
# Location with the minimum sales: Kansas (63 sales)

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Group the data by location and calculate the total purchase amount
location_sales = data.groupby('Location')['Purchase Amount (USD)'].sum().sort_values(ascending=False)

# Create a DataFrame for the heatmap
heatmap_data = pd.DataFrame(location_sales).reset_index()

# Plot the heatmap
plt.figure(figsize=(14, 8))
sns.heatmap(heatmap_data.pivot_table(index='Location', values='Purchase Amount (USD)'), annot=True, fmt='.2f', cmap='YlGnBu')
plt.title('Heatmap of Total Purchase Amount by Location')
plt.xlabel('Total Purchase Amount (USD)')
plt.ylabel('Location')
plt.show()

# %% [markdown]
# 1. **Top Performing Locations**: The locations with the highest sales can be identified. These locations are crucial for the business as they contribute significantly to the overall sales. For example, if California has the highest count, it indicates a strong customer base there.
#
# 2. **Underperforming Locations**: Similarly, the locations with the lowest sales can be identified. These areas might need targeted marketing efforts or further investigation to understand the low performance.
#
# 3. **Regional Trends**: The graph can reveal regional trends in customer behavior. For instance, certain regions might prefer specific products or have higher purchase frequencies.
#
# 4. **Resource Allocation**: Understanding which locations perform well and which do not can help in better resource allocation. More resources can be directed towards high-performing areas to maximize sales, while strategies can be developed to improve sales in low-performing areas.
#
# 5. **Market Expansion**: The data can also help in identifying potential markets for expansion. Locations with moderate sales but high potential can be targeted for growth.
#
# 6. **Customer Preferences**: The geographical distribution can provide insights into customer preferences in different regions, helping tailor marketing strategies to suit regional tastes and preferences.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# Load the data
data = pd.read_csv("shopping_trends.csv")

# Plot the box plot for sentiment analysis of reviews by item
plt.figure(figsize=(14, 8))
sns.boxplot(x='Item Purchased', y='Review Rating', data=data)
plt.title('Sentiment Analysis of Reviews by Individual Items')
plt.xlabel('Item Purchased')
plt.ylabel('Review Rating')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# 1. **Customer Satisfaction**: The distribution of review ratings for each item provides insights into customer satisfaction. Items with higher median ratings indicate higher customer satisfaction, while items with lower median ratings may need improvement.
#
# 2. **Consistency in Quality**: The spread of the ratings for each item can indicate the consistency in quality. A narrower spread suggests consistent quality, while a wider spread indicates variability in customer experiences.
#
# 3. **Outliers**: The presence of outliers in the box plot can highlight exceptional cases where customers had significantly better or worse experiences with certain items. These outliers can provide valuable feedback for product improvement.
#
# 4. **Popular Items**: Items with a higher number of reviews can be identified as popular products. These items are likely to have a larger customer base and can be prioritized for inventory and marketing efforts.
#
# 5. **Areas for Improvement**: Items with lower median ratings or a higher number of negative reviews can be identified as areas for improvement. Businesses can focus on addressing the issues with these items to enhance customer satisfaction.
#
# 6. **Product Performance Comparison**: By comparing the review ratings of different items, businesses can identify which products are performing well and which ones are not. This comparison can help in making data-driven decisions for product development and marketing strategies.

# %% [markdown]
# # Conclusion
#
# 1. **Age Distribution**: The age distribution of customers is fairly spread out, with a noticeable peak in the younger age groups. The majority of customers fall within the age range of 20-40 years.
#
# 2. **Gender Distribution**: There is a balanced distribution of male and female customers, with a slight majority of male customers.
#
# 3. **Product Category Distribution**: Clothing items are the most popular category, followed by accessories and footwear. Specifically, blouses, sweaters, and jeans are the top-selling items.
#
# 4. **Purchases by Season**: Purchases are relatively evenly distributed across different seasons, with a slight increase during the spring and winter seasons. Spring has the highest number of purchases, followed by winter.
#
# 5. **Shipping Preferences**: Express shipping is the most preferred shipping type among customers, followed by free shipping and next-day air.
#
# 6. **Discount Usage**: A significant number of customers use discounts when making purchases. The majority of purchases have discounts applied.
#
# 7. **Promo Code Usage**: Promo codes are also widely used by customers. A large proportion of purchases involve the use of promo codes.
#
# 8. **Frequency of Purchases**: Weekly and fortnightly purchases are the most common frequencies among customers. Monthly and quarterly purchases are less common.
#
# 9. **Customer Lifetime Value (CLV)**: There is a positive correlation between the frequency of purchases and the total purchase amount. Customers who purchase more frequently tend to have a higher total purchase amount.
#
# 10. **Impact of Discounts and Promo Codes**: Discounts and promo codes have a noticeable impact on the purchase amount. Higher purchase amounts are observed when discounts and promo codes are applied.
#
# 11. **Sales by Location**: Sales are distributed across various locations, with some states showing higher sales volumes. States like California, Texas, and New York have the highest sales volumes.
#
# 12. **Trend Analysis Over Time**: There is a general upward trend in the total purchase amount over time. Monthly sales show a steady increase, indicating growing customer engagement and spending.
#
# 13. **Review Rating Distribution**: The review ratings are generally positive, with most ratings falling in the higher range. The majority of products have ratings between 3.5 and 4.5.
